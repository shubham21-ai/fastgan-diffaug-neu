# %% [markdown]
# # FastGAN + DiffAugment Training on Kaggle
#
# This notebook automatically clones the latest fixed repository and runs the training loop. It's pre-configured to run smoothly on Kaggle's free tier GPUs with built-in SIGTERM emergency checkpointing.

# %%
# Clone the repository
# !git clone https://github.com/shubham21-ai/fastgan-diffaug-neu.git
# %cd fastgan-diffaug-neu
# !git pull origin main

# %%
# Install necessary dependencies
# !pip install pyyaml lpips

# %%
# Run the training script.
# NOTE: Make sure to click '+ Add Data' in Kaggle to attach your dataset,
# and update the --data_path below if the folder name is different.
# !python train.py \
    --data_path /kaggle/input/neu-surface-defect-database \
    --save_dir /kaggle/working/checkpoints \
    --config configs/neu_det_128.yaml
